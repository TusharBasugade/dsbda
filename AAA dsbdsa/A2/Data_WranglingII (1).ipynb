# %%
import pandas as pd

# %% [markdown]
# # New section

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8256593d-8c18-4a1a-920f-913ee886c9a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8256593d-8c18-4a1a-920f-913ee886c9a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
obj=pd.read_csv("/content/Academic_Performance.csv")

# %%
obj
# Out:
#     Roll_No            Name  Attendance  Math_Marks  English_Marks  \
# 0         1           Rohit        69.5        30.0           81.0
# 1         2           Virat        61.0        56.0            NaN
# 2         3      Christiano        80.0         NaN           35.0
# 3         4          Lionel        95.0        35.0           -5.0
# 4         5          Mbappe        55.0        95.0           62.0
# 5         6  Mahendra Singh        78.0        34.0           45.0
# 6         7           Sadio         NaN        65.0           85.0
# 7         8          Sergio        40.0        35.0           78.0
# 8         9          Bumrah        56.0        25.0           57.0
# 9        10         Shreyas        83.0        65.0            NaN
# 10       11           Rohit        69.5        30.0           81.0
# 11       12             NaN        61.0        56.0            NaN
# 12       13      Christiano        80.0       117.0           35.0
# ...

# %%
obj.head()
# Out:
#    Roll_No        Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1       Rohit        69.5        30.0           81.0           87.0
# 1        2       Virat        61.0        56.0            NaN           28.0
# 2        3  Christiano        80.0         NaN           35.0           45.0
# 3        4      Lionel        95.0        35.0           -5.0           89.0
# 4        5      Mbappe        55.0        95.0           62.0           68.0
#
#    Total_Marks  Percentage Result
# 0          198   66.000000   Pass
# 1           84   28.000000   Fail
# 2           80   26.666667   Fail
# 3          119   39.666667   Pass
# 4          225   75.000000   Pass

# %%
obj.tail()
# Out:
#     Roll_No     Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 15       16      NaN        88.0        34.0           45.0            NaN
# 16       17    Sadio         NaN        65.0           85.0           24.0
# 17       18   Sergio        40.0        35.0           78.0          134.0
# 18       19   Bumrah        56.0        25.0           57.0           15.0
# 19       20  Shreyas        65.0        65.0           51.0           89.0
#
#     Total_Marks  Percentage Result
# 15           79   26.333333   Fail
# 16          174   58.000000   Pass
# 17          247   82.333333   Pass
# 18           97   32.333333   Fail
# 19          205   68.333333   Pass

# %%
obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Roll_No        20 non-null     int64
#  1   Name           18 non-null     object
#  2   Attendance     18 non-null     float64
#  3   Math_Marks     19 non-null     float64
#  4   English_Marks  17 non-null     float64
#  5   Science_Marks  18 non-null     float64
#  6   Total_Marks    20 non-null     int64
#  7   Percentage     20 non-null     float64
#  8   Result         20 non-null     object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 1.5+ KB

# %%
obj.describe(include="all")
# Out:
#          Roll_No   Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# count   20.00000     18   18.000000   19.000000      17.000000      18.000000
# unique       NaN     10         NaN         NaN            NaN            NaN
# top          NaN  Rohit         NaN         NaN            NaN            NaN
# freq         NaN      2         NaN         NaN            NaN            NaN
# mean    10.50000    NaN   68.166667   50.315789      58.000000      56.500000
# std      5.91608    NaN   16.761300   24.678044      23.425414      35.921892
# min      1.00000    NaN   40.000000   25.000000      -5.000000     -15.000000
# 25%      5.75000    NaN   56.000000   34.000000      45.000000      29.000000
# 50%     10.50000    NaN   67.250000   35.000000      57.000000      54.000000
# 75%     15.25000    NaN   80.000000   65.000000      78.000000      87.000000
# max     20.00000    NaN   95.000000  117.000000      85.000000     134.000000
#
# ...

# %%
obj.shape
# Out:
# (20, 9)

# %%
obj.describe(include="all")
# Out:
#          Roll_No   Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# count   20.00000     18   18.000000   19.000000      17.000000      18.000000
# unique       NaN     10         NaN         NaN            NaN            NaN
# top          NaN  Rohit         NaN         NaN            NaN            NaN
# freq         NaN      2         NaN         NaN            NaN            NaN
# mean    10.50000    NaN   68.166667   50.315789      58.000000      56.500000
# std      5.91608    NaN   16.761300   24.678044      23.425414      35.921892
# min      1.00000    NaN   40.000000   25.000000      -5.000000     -15.000000
# 25%      5.75000    NaN   56.000000   34.000000      45.000000      29.000000
# 50%     10.50000    NaN   67.250000   35.000000      57.000000      54.000000
# 75%     15.25000    NaN   80.000000   65.000000      78.000000      87.000000
# max     20.00000    NaN   95.000000  117.000000      85.000000     134.000000
#
# ...

# %%
obj.shape
# Out:
# (20, 9)

# %%
obj.dtypes
# Out:
# Roll_No            int64
# Name              object
# Attendance       float64
# Math_Marks       float64
# English_Marks    float64
# Science_Marks    float64
# Total_Marks        int64
# Percentage       float64
# Result            object
# dtype: object

# %%
obj.columns
# Out:
# Index(['Roll_No', 'Name', 'Attendance', 'Math_Marks', 'English_Marks',
#        'Science_Marks', 'Total_Marks', 'Percentage', 'Result'],
#       dtype='object')

# %%
obj[0:5]
# Out:
#    Roll_No        Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1       Rohit        69.5        30.0           81.0           87.0
# 1        2       Virat        61.0        56.0            NaN           28.0
# 2        3  Christiano        80.0         NaN           35.0           45.0
# 3        4      Lionel        95.0        35.0           -5.0           89.0
# 4        5      Mbappe        55.0        95.0           62.0           68.0
#
#    Total_Marks  Percentage Result
# 0          198   66.000000   Pass
# 1           84   28.000000   Fail
# 2           80   26.666667   Fail
# 3          119   39.666667   Pass
# 4          225   75.000000   Pass

# %%
obj.loc[0:2]
# Out:
#    Roll_No        Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0        1       Rohit        69.5        30.0           81.0           87.0
# 1        2       Virat        61.0        56.0            NaN           28.0
# 2        3  Christiano        80.0         NaN           35.0           45.0
#
#    Total_Marks  Percentage Result
# 0          198   66.000000   Pass
# 1           84   28.000000   Fail
# 2           80   26.666667   Fail

# %%
obj.loc[0:2,'Math_Marks':'English_Marks']
# Out:
#    Math_Marks  English_Marks
# 0        30.0           81.0
# 1        56.0            NaN
# 2         NaN           35.0

# %%
obj.iloc[1:3]
# Out:
#    Roll_No        Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 1        2       Virat        61.0        56.0            NaN           28.0
# 2        3  Christiano        80.0         NaN           35.0           45.0
#
#    Total_Marks  Percentage Result
# 1           84   28.000000   Fail
# 2           80   26.666667   Fail

# %%
obj.iloc[1:3]
# Out:
#    Roll_No        Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 1        2       Virat        61.0        56.0            NaN           28.0
# 2        3  Christiano        80.0         NaN           35.0           45.0
#
#    Total_Marks  Percentage Result
# 1           84   28.000000   Fail
# 2           80   26.666667   Fail

# %%
obj.iloc[1:5,1:5]
# Out:
#          Name  Attendance  Math_Marks  English_Marks
# 1       Virat        61.0        56.0            NaN
# 2  Christiano        80.0         NaN           35.0
# 3      Lionel        95.0        35.0           -5.0
# 4      Mbappe        55.0        95.0           62.0

# %%
obj.isnull()
# Out:
#     Roll_No   Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0     False  False       False       False          False          False
# 1     False  False       False       False           True          False
# 2     False  False       False        True          False          False
# 3     False  False       False       False          False          False
# 4     False  False       False       False          False          False
# 5     False  False       False       False          False          False
# 6     False  False        True       False          False          False
# 7     False  False       False       False          False          False
# 8     False  False       False       False          False           True
# 9     False  False       False       False           True          False
# 10    False  False       False       False          False          False
# 11    False   True       False       False           True          False
# ...

# %%
obj.isna()
# Out:
#     Roll_No   Name  Attendance  Math_Marks  English_Marks  Science_Marks  \
# 0     False  False       False       False          False          False
# 1     False  False       False       False           True          False
# 2     False  False       False        True          False          False
# 3     False  False       False       False          False          False
# 4     False  False       False       False          False          False
# 5     False  False       False       False          False          False
# 6     False  False        True       False          False          False
# 7     False  False       False       False          False          False
# 8     False  False       False       False          False           True
# 9     False  False       False       False           True          False
# 10    False  False       False       False          False          False
# 11    False   True       False       False           True          False
# ...

# %%
obj.isnull().any()
# Out:
# Roll_No          False
# Name              True
# Attendance        True
# Math_Marks        True
# English_Marks     True
# Science_Marks     True
# Total_Marks      False
# Percentage       False
# Result           False
# dtype: bool

# %%
obj.isnull().sum()
# Out:
# Roll_No          0
# Name             2
# Attendance       2
# Math_Marks       1
# English_Marks    3
# Science_Marks    2
# Total_Marks      0
# Percentage       0
# Result           0
# dtype: int64

# %%
obj.Attendance.isnull().sum()
# Out:
# 2

# %%
cols_with_na = []
for col in obj.columns:
  if obj[col].isna().any():
    cols_with_na.append(col)
cols_with_na
# Out:
# ['Name', 'Attendance', 'Math_Marks', 'English_Marks', 'Science_Marks']

# %%
import numpy as np

# %%
obj.replace(np.nan,value=0)
# Out:
#     Roll_No            Name  Attendance  Math_Marks  English_Marks  \
# 0         1           Rohit        69.5        30.0           81.0
# 1         2           Virat        61.0        56.0            0.0
# 2         3      Christiano        80.0         0.0           35.0
# 3         4          Lionel        95.0        35.0           -5.0
# 4         5          Mbappe        55.0        95.0           62.0
# 5         6  Mahendra Singh        78.0        34.0           45.0
# 6         7           Sadio         0.0        65.0           85.0
# 7         8          Sergio        40.0        35.0           78.0
# 8         9          Bumrah        56.0        25.0           57.0
# 9        10         Shreyas        83.0        65.0            0.0
# 10       11           Rohit        69.5        30.0           81.0
# 11       12               0        61.0        56.0            0.0
# 12       13      Christiano        80.0       117.0           35.0
# ...

# %%
obj.fillna(1)
# Out:
#     Roll_No            Name  Attendance  Math_Marks  English_Marks  \
# 0         1           Rohit        69.5        30.0           81.0
# 1         2           Virat        61.0        56.0            1.0
# 2         3      Christiano        80.0         1.0           35.0
# 3         4          Lionel        95.0        35.0           -5.0
# 4         5          Mbappe        55.0        95.0           62.0
# 5         6  Mahendra Singh        78.0        34.0           45.0
# 6         7           Sadio         1.0        65.0           85.0
# 7         8          Sergio        40.0        35.0           78.0
# 8         9          Bumrah        56.0        25.0           57.0
# 9        10         Shreyas        83.0        65.0            1.0
# 10       11           Rohit        69.5        30.0           81.0
# 11       12               1        61.0        56.0            1.0
# 12       13      Christiano        80.0       117.0           35.0
# ...

# %%
obj['Math_Marks']=obj['Math_Marks'].fillna(obj['Math_Marks'].mean())

# %%
obj['Math_Marks']
# Out:
# 0      30.000000
# 1      56.000000
# 2      50.315789
# 3      35.000000
# 4      95.000000
# 5      34.000000
# 6      65.000000
# 7      35.000000
# 8      25.000000
# 9      65.000000
# 10     30.000000
# 11     56.000000
# 12    117.000000
# 13     35.000000
# 14     54.000000
# 15     34.000000
# 16     65.000000
# 17     35.000000
# 18     25.000000
# 19     65.000000
# Name: Math_Marks, dtype: float64

# %%
obj.head(10)
# Out:
#    Roll_No            Name  Attendance  Math_Marks  English_Marks  \
# 0        1           Rohit        69.5   30.000000           81.0
# 1        2           Virat        61.0   56.000000            NaN
# 2        3      Christiano        80.0   50.315789           35.0
# 3        4          Lionel        95.0   35.000000           -5.0
# 4        5          Mbappe        55.0   95.000000           62.0
# 5        6  Mahendra Singh        78.0   34.000000           45.0
# 6        7           Sadio         NaN   65.000000           85.0
# 7        8          Sergio        40.0   35.000000           78.0
# 8        9          Bumrah        56.0   25.000000           57.0
# 9       10         Shreyas        83.0   65.000000            NaN
#
#    Science_Marks  Total_Marks  Percentage Result
# 0           87.0          198   66.000000   Pass
# 1           28.0           84   28.000000   Fail
# 2           45.0           80   26.666667   Fail
# ...

# %%
obj.dropna() #Dropping rows with at least 1 null value
# Out:
#     Roll_No            Name  Attendance  Math_Marks  English_Marks  \
# 0         1           Rohit        69.5   30.000000           81.0
# 2         3      Christiano        80.0   50.315789           35.0
# 3         4          Lionel        95.0   35.000000           -5.0
# 4         5          Mbappe        55.0   95.000000           62.0
# 5         6  Mahendra Singh        78.0   34.000000           45.0
# 7         8          Sergio        40.0   35.000000           78.0
# 10       11           Rohit        69.5   30.000000           81.0
# 12       13      Christiano        80.0  117.000000           35.0
# 13       14          Lionel        95.0   35.000000           54.0
# 14       15          Mbappe        55.0   54.000000           62.0
# 17       18          Sergio        40.0   35.000000           78.0
# 18       19          Bumrah        56.0   25.000000           57.0
# 19       20         Shreyas        65.0   65.000000           51.0
#
# ...

# %%
obj.dropna(how="all") #Dropping rows if all values in that row are missing
# Out:
#     Roll_No            Name  Attendance  Math_Marks  English_Marks  \
# 0         1           Rohit        69.5   30.000000           81.0
# 1         2           Virat        61.0   56.000000            NaN
# 2         3      Christiano        80.0   50.315789           35.0
# 3         4          Lionel        95.0   35.000000           -5.0
# 4         5          Mbappe        55.0   95.000000           62.0
# 5         6  Mahendra Singh        78.0   34.000000           45.0
# 6         7           Sadio         NaN   65.000000           85.0
# 7         8          Sergio        40.0   35.000000           78.0
# 8         9          Bumrah        56.0   25.000000           57.0
# 9        10         Shreyas        83.0   65.000000            NaN
# 10       11           Rohit        69.5   30.000000           81.0
# 11       12             NaN        61.0   56.000000            NaN
# 12       13      Christiano        80.0  117.000000           35.0
# ...

# %%
obj.dropna(axis=1) #Dropping columns with at least 1 null value.
# Out:
#     Roll_No  Math_Marks  Total_Marks  Percentage Result
# 0         1   30.000000          198   66.000000   Pass
# 1         2   56.000000           84   28.000000   Fail
# 2         3   50.315789           80   26.666667   Fail
# 3         4   35.000000          119   39.666667   Pass
# 4         5   95.000000          225   75.000000   Pass
# 5         6   34.000000           64   21.333333   Fail
# 6         7   65.000000          174   58.000000   Pass
# 7         8   35.000000          167   55.666667   Pass
# 8         9   25.000000           82   27.333333   Fail
# 9        10   65.000000          154   51.333333   Pass
# 10       11   30.000000          198   66.000000   Pass
# 11       12   56.000000          110   36.666667   Pass
# 12       13  117.000000          197   65.666667   Pass
# 13       14   35.000000          121   40.333333   Pass
# 14       15   54.000000          184   61.333333   Pass
# 15       16   34.000000           79   26.333333   Fail
# ...

# %%
obj.dropna(axis=0,inplace=True) #Dropping Rows with at least 1 null value in CSV file

# %%
obj
# Out:
#     Roll_No            Name  Attendance  Math_Marks  English_Marks  \
# 0         1           Rohit        69.5   30.000000           81.0
# 2         3      Christiano        80.0   50.315789           35.0
# 3         4          Lionel        95.0   35.000000           -5.0
# 4         5          Mbappe        55.0   95.000000           62.0
# 5         6  Mahendra Singh        78.0   34.000000           45.0
# 7         8          Sergio        40.0   35.000000           78.0
# 10       11           Rohit        69.5   30.000000           81.0
# 12       13      Christiano        80.0  117.000000           35.0
# 13       14          Lionel        95.0   35.000000           54.0
# 14       15          Mbappe        55.0   54.000000           62.0
# 17       18          Sergio        40.0   35.000000           78.0
# 18       19          Bumrah        56.0   25.000000           57.0
# 19       20         Shreyas        65.0   65.000000           51.0
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(obj)
# Out:
# <Axes: >

# %%
obj.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x=obj.Total_Marks)
# Out:
# <Axes: xlabel='Total_Marks'>

# %%
sns.boxplot(x=obj.Percentage)
# Out:
# <Axes: xlabel='Percentage'>

# %%
sns.boxplot(x=obj.Math_Marks)
# Out:
# <Axes: xlabel='Math_Marks'>

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9, 6)
df_list = ['Roll_No','Math_Marks','Total_Marks','Percentage']
fig, axes = plt.subplots(2, 2)
fig.set_dpi(120)
count=0
for r in range(2):
  for c in range(2):
    _ = obj[df_list[count]].plot(kind = 'box', ax=axes[r,c])
    count+=1

# %%
Lower_limit=0
Upper_limit=100
print(f'Lower_limit = {Lower_limit}, Upper_limit = {Upper_limit}')
# Out:
# Lower_limit = 0, Upper_limit = 100

# %%
obj[(obj['Percentage'] < Lower_limit) | (obj['Percentage'] > Upper_limit)] # outlier data
# Out:
# Empty DataFrame
# Columns: [Roll_No, Name, Attendance, Math_Marks, English_Marks, Science_Marks, Total_Marks, Percentage, Result]
# Index: []

# %%
outliers=[]
for i in obj.Percentage:
  if i<Lower_limit or i>Upper_limit:
    outliers.append(i)
print("outliers are",outliers)
# Out:
# outliers are []

# %%
Upper_limit
# Out:
# 100

# %%
Lower_limit
# Out:
# 0

# %%
obj[obj.Percentage<Lower_limit].index
# Out:
# Index([], dtype='int64')

# %%
obj1=obj.drop(obj[obj.Percentage<Lower_limit].index) #normal data without outlier

# %%
obj1.shape
# Out:
# (13, 9)

# %%
#outlier data
obj2=obj[obj.Percentage<Lower_limit]
obj2
# Out:
# Empty DataFrame
# Columns: [Roll_No, Name, Attendance, Math_Marks, English_Marks, Science_Marks, Total_Marks, Percentage, Result]
# Index: []

# %%
sns.kdeplot(obj.Percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
sns.kdeplot(obj1.Percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
sns.kdeplot(obj1.Percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
log_percentage=np.log(obj.Percentage)
log_percentage
# Out:
# 0     4.189655
# 2     3.283414
# 3     3.680511
# 4     4.317488
# 5     3.060271
# 7     4.019382
# 10    4.189655
# 12    4.184591
# 13    3.697178
# 14    4.116323
# 17    4.410776
# 18    3.476099
# 19    4.224398
# Name: Percentage, dtype: float64

# %%
sns.kdeplot(log_percentage)
# Out:
# <Axes: xlabel='Percentage', ylabel='Density'>

# %%
import seaborn as sns

# %%
obj.replace({'Pass': 1, 'Fail': 0}, inplace=True)

# %%
 obj = obj.drop(['Name'], axis=1)
# obj = obj.drop(['Result'], axis=1)

# %%
#skewness in the data
obj.skew()
# Out:
# Roll_No          0.057321
# Attendance      -0.013641
# Math_Marks       1.667305
# English_Marks   -1.189793
# Science_Marks   -0.211156
# Total_Marks     -0.381643
# Percentage      -0.381643
# Result          -1.451132
# dtype: float64

# %%
sns.kdeplot(obj.Attendance);

# %%
sns.kdeplot(obj.Math_Marks);

# %%
sns.kdeplot(obj.English_Marks);

# %%
sns.kdeplot(obj.Science_Marks);

# %%
sns.kdeplot(obj.Total_Marks);

# %%
sns.kdeplot(obj.Percentage);
